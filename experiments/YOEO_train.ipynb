# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# !unzip /content/gdrive/MyDrive/simulation.zip -d /content/gdrive/MyDrive/Simulation

# %%
# !git clone https://github.com/bit-bots/YOEO.git

# %%
# %cd yoeo

# %%
# !pip3 install poetry

# %%
# !poetry install --no-ansi

# %%
# !poetry run yoeo-train -d config/yoeo_gdrive.data --pretrained_weights content/gdrive/MyDrive/weights/yoeo.pth --checkpoint_dir content/gdrive/MyDrive/checkpoints_default --logdir content/gdrive/MyDrive/logs

# %% [markdown]
# Change scheduler settings:

# %%
# !poetry run yoeo-train -d config/yoeo_gdrive.data --pretrained_weights content/gdrive/MyDrive/weights/yoeo.pth --checkpoint_dir content/gdrive/MyDrive/checkpoints_default --logdir content/gdrive/MyDrive/logs

# %% [markdown]
# Add flips proba:

# %%
# !poetry run yoeo-train -d config/yoeo_gdrive.data --pretrained_weights content/gdrive/MyDrive/checkpoints/yoeo_best.pth --checkpoint_dir content/gdrive/MyDrive/checkpoints_default --logdir content/gdrive/MyDrive/logs

# %% [markdown]
# ##Lines

# %%
# !git clone --branch yoeo_lines https://github.com/ShulzhenkoPetr/Segmentation_Starkit_MIPT.git

# %%
# %cd Segmentation_Starkit_MIPT/yoeo
# Out:
# /content/Segmentation_Starkit_MIPT/yoeo

# %%
# !pip3 install poetry

# %%
#After a change in .toml
# !poetry lock
# Out:
# Creating virtualenv yoeo-USBD7Q3l-py3.10 in /root/.cache/pypoetry/virtualenvs
# Updating dependencies
# Resolving dependencies... (22.4s)
#
# Writing lock file

# %%
# !poetry install --no-ansi

# %% [markdown]
# Test lines:

# %%
# !poetry run yoeo-test --data config/yoeo_gdrive.data --weights ../../gdrive/MyDrive/weights/yoeo2.pth --n_cpu 8
# Out:
# Environment information:
# System: Linux 5.10.147+
# Current Version: yoeo 1.2.3
# Current Commit Hash: 4accae7
# Command line arguments: Namespace(model='config/yoeo_lines.cfg', weights='../../gdrive/MyDrive/weights/yoeo2.pth', data='config/yoeo_gdrive.data', batch_size=8, verbose=False, img_size=416, n_cpu=8, iou_thres=0.5, conf_thres=0.01, nms_thres=0.4)
# {'detection': ['ball', 'goalpost', 'robot'], 'segmentation': ['background', 'lines']}
# /root/.cache/pypoetry/virtualenvs/yoeo-USBD7Q3l-py3.10/lib/python3.10/site-packages/torch/utils/data/dataloader.py:563: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# ...

# %%
# !poetry run yoeo-train -d config/yoeo_gdrive.data --pretrained_weights ../../gdrive/MyDrive/weights/yoeo2.pth --checkpoint_dir ../../gdrive/MyDrive/checkpoints
# Out:
# Environment information:
# System: Linux 5.10.147+
# Current Version: yoeo 1.2.3
# Current Commit Hash: 4accae7
# Command line arguments: Namespace(model='config/yoeo_lines.cfg', data='config/yoeo_gdrive.data', epochs=300, verbose=False, n_cpu=8, pretrained_weights='../../gdrive/MyDrive/weights/yoeo2.pth', checkpoint_interval=1, checkpoint_dir='../../gdrive/MyDrive/checkpoints', evaluation_interval=1, multiscale_training=False, iou_thres=0.5, conf_thres=0.1, nms_thres=0.5, logdir='logs', seed=-1)
# cuda
# /root/.cache/pypoetry/virtualenvs/yoeo-USBD7Q3l-py3.10/lib/python3.10/site-packages/torch/utils/data/dataloader.py:563: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
# ...

# %%
# !poetry run yoeo-train -d config/yoeo_gdrive.data --pretrained_weights ../../gdrive/MyDrive/checkpoints/yoeo_checkpoint_3.pth --checkpoint_dir ../../gdrive/MyDrive/checkpoints --logdir ../../gdrive/MyDrive/logs
# Out:
# Environment information:
# System: Linux 5.10.147+
# Current Version: yoeo 1.2.3
# Current Commit Hash: 4accae7
# Command line arguments: Namespace(model='config/yoeo_lines.cfg', data='config/yoeo_gdrive.data', epochs=300, verbose=False, n_cpu=8, pretrained_weights='../../gdrive/MyDrive/checkpoints/yoeo_checkpoint_3.pth', checkpoint_interval=1, checkpoint_dir='../../gdrive/MyDrive/checkpoints', evaluation_interval=1, multiscale_training=False, iou_thres=0.5, conf_thres=0.1, nms_thres=0.5, logdir='../../gdrive/MyDrive/logs', seed=-1)
# cuda
# ...

# %% [markdown]
# ###Added simulation test images in training set:

# %%
# !poetry run yoeo-train -d config/yoeo_gdrive.data --pretrained_weights ../../gdrive/MyDrive/weights/yoeo2.pth --checkpoint_dir ../../gdrive/MyDrive/checkpoints --logdir ../../gdrive/MyDrive/logs
# Out:
# Environment information:
# System: Linux 5.10.147+
# Current Version: yoeo 1.2.3
# Current Commit Hash: 4accae7
# Command line arguments: Namespace(model='config/yoeo_lines.cfg', data='config/yoeo_gdrive.data', epochs=300, verbose=False, n_cpu=8, pretrained_weights='../../gdrive/MyDrive/weights/yoeo2.pth', checkpoint_interval=1, checkpoint_dir='../../gdrive/MyDrive/checkpoints', evaluation_interval=1, multiscale_training=False, iou_thres=0.5, conf_thres=0.1, nms_thres=0.5, logdir='../../gdrive/MyDrive/logs', seed=-1)
# cuda
#
# ---- Training Model ----
# Training Epoch 1: 100% 1562/1562 [1:04:53<00:00,  2.49s/it]
# ---- Saving checkpoint to: '../../gdrive/MyDrive/checkpoints/yoeo_checkpoint_1.pth' ----
#
# ---- Evaluating Model ----
# Validating: 100% 197/197 [07:24<00:00,  2.26s/it]
# Times: Mean 158.62008695062912fps | Std: 0.003716677945078892 ms
# Computing AP: 100% 3/3 [00:00<00:00, 421.48it/s]
# [0.992374987844299, 0.6035036321870219]
# ---- mAP 0.77236 ----
# ...

# %% [markdown]
# Start with epoch 11 (as it's the best score) and proceeed by decreasing lr to 1e-4

# %%
# !poetry run yoeo-train -d config/yoeo_gdrive.data --pretrained_weights ../../gdrive/MyDrive/checkpoints/yoeo_checkpoint_11.pth --checkpoint_dir ../../gdrive/MyDrive/checkpoints --logdir ../../gdrive/MyDrive/logs
# Out:
# Environment information:
# System: Linux 5.10.147+
# Current Version: yoeo 1.2.3
# Current Commit Hash: 4accae7
# Command line arguments: Namespace(model='config/yoeo_lines.cfg', data='config/yoeo_gdrive.data', epochs=300, verbose=False, n_cpu=8, pretrained_weights='../../gdrive/MyDrive/checkpoints/yoeo_checkpoint_11.pth', checkpoint_interval=1, checkpoint_dir='../../gdrive/MyDrive/checkpoints', evaluation_interval=1, multiscale_training=False, iou_thres=0.5, conf_thres=0.1, nms_thres=0.5, logdir='../../gdrive/MyDrive/logs', seed=-1)
# cuda
# ...

# %% [markdown]
# Best after 20 epoch -> let's decrease lr again to 1e-5

# %%
# !poetry run yoeo-train -d config/yoeo_gdrive.data --pretrained_weights ../../gdrive/MyDrive/checkpoints/yoeo_smaller_lr_checkpoint_20.pth --checkpoint_dir ../../gdrive/MyDrive/checkpoints --logdir ../../gdrive/MyDrive/logs
# Out:
# Environment information:
# System: Linux 5.10.147+
# Current Version: yoeo 1.2.3
# Current Commit Hash: 4accae7
# Command line arguments: Namespace(model='config/yoeo_lines.cfg', data='config/yoeo_gdrive.data', epochs=300, verbose=False, n_cpu=8, pretrained_weights='../../gdrive/MyDrive/checkpoints/yoeo_smaller_lr_checkpoint_20.pth', checkpoint_interval=1, checkpoint_dir='../../gdrive/MyDrive/checkpoints', evaluation_interval=1, multiscale_training=False, iou_thres=0.5, conf_thres=0.1, nms_thres=0.5, logdir='../../gdrive/MyDrive/logs', seed=-1)
# cuda
# ...

# %% [markdown]
# # Focal LOSS

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# !git clone --branch yoeo-lines-new-loss https://github.com/ShulzhenkoPetr/Segmentation_Starkit_MIPT.git

# %%
# %cd Segmentation_Starkit_MIPT/yoeo
# Out:
# /content/Segmentation_Starkit_MIPT/yoeo

# %%
# !pip3 install poetry

# %%
# !poetry install --no-ansi

# %% [markdown]
# lr = 1e-3

# %%
# !poetry run yoeo-train -d config/yoeo_gdrive.data \
  --pretrained_weights /content/gdrive/MyDrive/weights/yoeo2.pth \
  --checkpoint_dir /content/gdrive/MyDrive/yoeo_focal_loss_checkpoints \
  --logdir /content/gdrive/MyDrive/yoeo_focal_loss_logs
# Out:
# Environment information:
# System: Linux 5.15.107+
# Current Version: yoeo 1.2.3
# Current Commit Hash: 24baf98
# Command line arguments: Namespace(model='config/yoeo_lines.cfg', data='config/yoeo_gdrive.data', epochs=300, verbose=False, n_cpu=8, pretrained_weights='/content/gdrive/MyDrive/weights/yoeo2.pth', checkpoint_interval=1, checkpoint_dir='/content/gdrive/MyDrive/yoeo_focal_loss_checkpoints', evaluation_interval=1, multiscale_training=False, iou_thres=0.5, conf_thres=0.1, nms_thres=0.5, logdir='/content/gdrive/MyDrive/yoeo_focal_loss_logs', seed=-1)
# cuda
# ...

# %% [markdown]
# lr 1e-4

# %%
# !poetry run yoeo-train -d config/yoeo_gdrive.data \
  --pretrained_weights /content/gdrive/MyDrive/yoeo_focal_loss_checkpoints/yoeo_checkpoint_2.pth \
  --checkpoint_dir /content/gdrive/MyDrive/yoeo_focal_loss_checkpoints \
  --logdir /content/gdrive/MyDrive/yoeo_focal_loss_logs
# Out:
# Environment information:
# System: Linux 5.15.107+
# Current Version: yoeo 1.2.3
# Current Commit Hash: 24baf98
# Command line arguments: Namespace(model='config/yoeo_lines.cfg', data='config/yoeo_gdrive.data', epochs=300, verbose=False, n_cpu=8, pretrained_weights='/content/gdrive/MyDrive/yoeo_focal_loss_checkpoints/yoeo_checkpoint_2.pth', checkpoint_interval=1, checkpoint_dir='/content/gdrive/MyDrive/yoeo_focal_loss_checkpoints', evaluation_interval=1, multiscale_training=False, iou_thres=0.5, conf_thres=0.1, nms_thres=0.5, logdir='/content/gdrive/MyDrive/yoeo_focal_loss_logs', seed=-1)
# cuda
# ...

# %% [markdown]
# ### Morph loss with lr 1e-3 and loss components ratio 0.5

# %%
# !poetry run yoeo-train -d config/yoeo_gdrive.data \
  --pretrained_weights /content/gdrive/MyDrive/weights/yoeo2.pth \
  --checkpoint_dir /content/gdrive/MyDrive/yoeo-lines-morph-checkpoints \
  --logdir /content/gdrive/MyDrive/yoeo-lines-morph-logs
# Out:
# Environment information:
# System: Linux 5.15.107+
# Current Version: yoeo 1.2.3
# Current Commit Hash: 1756534
# Command line arguments: Namespace(model='config/yoeo_lines.cfg', data='config/yoeo_gdrive.data', epochs=300, verbose=False, n_cpu=8, pretrained_weights='/content/gdrive/MyDrive/weights/yoeo2.pth', checkpoint_interval=1, checkpoint_dir='/content/gdrive/MyDrive/yoeo-lines-morph-checkpoints', evaluation_interval=1, multiscale_training=False, iou_thres=0.5, conf_thres=0.1, nms_thres=0.5, logdir='/content/gdrive/MyDrive/yoeo-lines-morph-logs', seed=-1)
# cuda
# ...

# %% [markdown]
# lr 1e-4

# %%
# !poetry run yoeo-train -d config/yoeo_gdrive.data \
  --pretrained_weights /content/gdrive/MyDrive/yoeo-lines-morph-checkpoints/yoeo_checkpoint_6-1e-3.pth \
  --checkpoint_dir /content/gdrive/MyDrive/yoeo-lines-morph-checkpoints \
  --logdir /content/gdrive/MyDrive/yoeo-lines-morph-logs
# Out:
# Environment information:
# System: Linux 5.15.107+
# Current Version: yoeo 1.2.3
# Current Commit Hash: 1756534
# Command line arguments: Namespace(model='config/yoeo_lines.cfg', data='config/yoeo_gdrive.data', epochs=300, verbose=False, n_cpu=8, pretrained_weights='/content/gdrive/MyDrive/yoeo-lines-morph-checkpoints/yoeo_checkpoint_6-1e-3.pth', checkpoint_interval=1, checkpoint_dir='/content/gdrive/MyDrive/yoeo-lines-morph-checkpoints', evaluation_interval=1, multiscale_training=False, iou_thres=0.5, conf_thres=0.1, nms_thres=0.5, logdir='/content/gdrive/MyDrive/yoeo-lines-morph-logs', seed=-1)
# cuda
# ...

# %% [markdown]
# lr 1e-5

# %%
# !poetry run yoeo-train -d config/yoeo_gdrive.data \
  --pretrained_weights /content/gdrive/MyDrive/yoeo-lines-morph-checkpoints/yoeo_checkpoint_12-1e-4.pth \
  --checkpoint_dir /content/gdrive/MyDrive/yoeo-lines-morph-checkpoints \
  --logdir /content/gdrive/MyDrive/yoeo-lines-morph-logs
# Out:
# Environment information:
# System: Linux 5.15.107+
# Current Version: yoeo 1.2.3
# Current Commit Hash: 1756534
# Command line arguments: Namespace(model='config/yoeo_lines.cfg', data='config/yoeo_gdrive.data', epochs=300, verbose=False, n_cpu=8, pretrained_weights='/content/gdrive/MyDrive/yoeo-lines-morph-checkpoints/yoeo_checkpoint_12-1e-4.pth', checkpoint_interval=1, checkpoint_dir='/content/gdrive/MyDrive/yoeo-lines-morph-checkpoints', evaluation_interval=1, multiscale_training=False, iou_thres=0.5, conf_thres=0.1, nms_thres=0.5, logdir='/content/gdrive/MyDrive/yoeo-lines-morph-logs', seed=-1)
# cuda
# ...

# %%
# !poetry run yoeo-train -d config/yoeo_gdrive.data \
  --pretrained_weights /content/gdrive/MyDrive/yoeo-lines-morph-checkpoints/yoeo_checkpoint_1.pth \
  --checkpoint_dir /content/gdrive/MyDrive/yoeo-lines-morph-checkpoints \
  --logdir /content/gdrive/MyDrive/yoeo-lines-morph-logs
# Out:
# Environment information:
# System: Linux 5.15.107+
# Current Version: yoeo 1.2.3
# Current Commit Hash: 1756534
# Command line arguments: Namespace(model='config/yoeo_lines.cfg', data='config/yoeo_gdrive.data', epochs=300, verbose=False, n_cpu=8, pretrained_weights='/content/gdrive/MyDrive/yoeo-lines-morph-checkpoints/yoeo_checkpoint_1.pth', checkpoint_interval=1, checkpoint_dir='/content/gdrive/MyDrive/yoeo-lines-morph-checkpoints', evaluation_interval=1, multiscale_training=False, iou_thres=0.5, conf_thres=0.1, nms_thres=0.5, logdir='/content/gdrive/MyDrive/yoeo-lines-morph-logs', seed=-1)
# cuda
# ...
